# %%
import sys

# %%
print("HI")
# Out:
# HI

# %%
#exception Handling
try:
    a=9/0
    print(a)
except Exception as e:
    _,_,trc_back=sys.exc_info()

#main function
    # child function
# Out:
# division by zero
